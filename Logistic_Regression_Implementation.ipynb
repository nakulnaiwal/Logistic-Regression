# %% [markdown]
# <a href="https://colab.research.google.com/github/nakulnaiwal/Logistic-Regression/blob/main/Logistic_Regression_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification
import numpy as np

# %%
X,Y = make_classification(n_samples=100,
                          n_features=2,
                          n_informative=2,
                          n_redundant=0,
                          n_clusters_per_class=1,
                          random_state=2,
                          hypercube=False,
                          class_sep=20)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=Y,cmap='winter',s=100)

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression(solver='sag',penalty=None)
lor.fit(X,Y)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(penalty=None, solver='sag')

# %%
print(lor.coef_)
print(lor.intercept_)
# Out:
# [[1.68090364 0.31252115]]
# [-1.41412776]

# %%
m1 = -(lor.coef_[0][0]/lor.coef_[0][1])
b1 = -(lor.intercept_/lor.coef_[0][1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m1*x_input + b1

# %%
def gd(X,y):

    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.5

    for i in range(5000):
        y_hat = sigmoid(np.dot(X,weights))
        weights = weights + lr*(np.dot((y-y_hat),X)/X.shape[0])

    return weights[1:],weights[0]

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
coef_,intercept_ = gd(X,Y)

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input1 + b

# %%
plt.figure(figsize=(6,4))

plt.scatter(X[:,0], X[:,1], c=Y, cmap='winter', s=100)

plt.plot(x_input, y_input, color='red', linewidth=3)
plt.plot(x_input1, y_input1, color='black', linewidth=3)

plt.xlim(X[:,0].min()-2, X[:,0].max()+2)
plt.ylim(X[:,1].min()-2, X[:,1].max()+2)

plt.show()

# %%
np.insert(X,0,1,axis=1)
# Out:
# array([[ 1.        ,  5.70732088,  1.83451071],
#        [ 1.        ,  3.38643307,  4.99462905],
#        [ 1.        ,  1.86010165,  4.40301639],
#        [ 1.        ,  2.14393009,  4.79021745],
#        [ 1.        , -2.2425174 ,  4.48512791],
#        [ 1.        ,  3.28101453,  3.20252617],
#        [ 1.        ,  2.82595719,  3.07748747],
#        [ 1.        , -3.16465395,  3.87534858],
#        [ 1.        ,  2.41511242,  4.56721942],
#        [ 1.        , -5.05112122,  4.10879523],
#        [ 1.        ,  3.55479751,  2.62182849],
#        [ 1.        ,  1.71420255,  4.42075757],
#        [ 1.        ,  1.98853338,  3.72112924],
#        [ 1.        ,  3.07570215,  3.90933787],
#        [ 1.        , -4.32907607,  4.61342236],
#        [ 1.        ,  2.6537724 ,  3.33938393],
#        [ 1.        , -5.45663137,  4.3885043 ],
#        [ 1.        ,  4.37244258,  1.09327242],
#        [ 1.        ,  3.0977523 ,  4.26186396],
#        [ 1.        ,  3.49767477,  4.11183018],
# ...

# %%
X1 = np.insert(X,0,1,axis=1)
np.ones(X1.shape[1])
# Out:
# array([1., 1., 1.])
